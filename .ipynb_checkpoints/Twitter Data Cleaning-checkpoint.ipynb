# %% [markdown]
# # Import modules

# %%
import pandas as pd
import html
import numpy as np
import re

# %% [markdown]
# # data pre-processing

# %%
data = pd.read_csv('sample.csv')

# %%
data
# Out:
#                   Tweet Id                                          Tweet URL  \
# 0    "1167429261210218497"  https://twitter.com/animalhealthEU/status/1167...
# 1    "1167375334670557185"  https://twitter.com/PennyBrohnUK/status/116737...
# 2    "1167237977615097861"  https://twitter.com/lordbyronaf/status/1167237...
# 3    "1167236897078480898"  https://twitter.com/CountessDavis/status/11672...
# 4    "1167228378191204353"  https://twitter.com/Local12/status/11672283781...
# ..                     ...                                                ...
# 381  "1145652120034717696"  https://twitter.com/UKNOAH/status/114565212003...
# 382  "1145637718493290497"  https://twitter.com/EMOverEasy/status/11456377...
# 383  "1145628612739174400"  https://twitter.com/SIMV_RP/status/11456286127...
# 384  "1145621305825341440"  https://twitter.com/wameyokw/status/1145621305...
# 385  "1145609117618397184"  https://twitter.com/animalhealthEU/status/1145...
#
#     Tweet Posted Time (UTC)  \
# ...

# %%
tweets = data['Tweet Content']
tweets
# Out:
# 0      Pets change our lives &amp; become a part of o...
# 1      Another spot of our #morethanmedicine bus in #...
# 2      What a great team ⁦@HealthSourceOH⁩ ⁦@Local12⁩...
# 3      What a great team ⁦@HealthSourceOH⁩ ⁦@Local12⁩...
# 4      What a great team ⁦@HealthSourceOH⁩ ⁦@Local12⁩...
#                              ...
# 381    #MorethanMedicine What does this mean? 🤔\nBy p...
# 382    After a great weekend at #rebellion19 we are b...
# 383    #MorethanMedicine What does this mean? 🤔\nBy p...
# 384    #MorethanMedicine What does this mean? 🤔\nBy p...
# 385    #MorethanMedicine What does this mean? 🤔\nBy p...
# Name: Tweet Content, Length: 386, dtype: object

# %% [markdown]
# # Decode HTML Entities and Cleaning Newlines
#
# So, far we already got the tweets but there are encoded html entities and newlines (\n) inside the tweets and we need to decode them first.

# %%
clean_data = [None] * len(tweets)
for i in range (len(tweets)):
    x = tweets[i].replace("\n"," ") #cleaning newline "\n" from the tweets
    clean_data[i] = html.unescape(x)

# %%
clean_data
# Out:
# ["Pets change our lives & become a part of our families ❤️ That's why our members offer many solutions to help you to enjoy a long-lasting bond with your happy & healthy pet 🐱🐶 #MorethanMedicine #PetCare #PetsareFamily https://t.co/fZNIXge9a3",
#  'Another spot of our #morethanmedicine bus in #bristol this week! If you need support with your cancer diagnosis call us on 0303 3000 118. #livingwellwithcancer https://t.co/eZGLz0BkXB',
#  'What a great team \u2066@HealthSourceOH\u2069 \u2066@Local12\u2069 #morethanmedicine https://t.co/g2YzMDUpVA',
#  'What a great team \u2066@HealthSourceOH\u2069 \u2066@Local12\u2069 #morethanmedicine https://t.co/g2YzMDUpVA',
#  'What a great team \u2066@HealthSourceOH\u2069 \u2066@Local12\u2069 #morethanmedicine https://t.co/g2YzMDUpVA',
#  'What a great team \u2066@HealthSourceOH\u2069 \u2066@Local12\u2069 #morethanmedicine https://t.co/g2YzMDUpVA',
# ...

# %% [markdown]
# # Cleaning Links using regex

# %%
for i in range (len(clean_data)):
    clean_data[i] = re.sub(r"http\S+", "", clean_data[i])

# %%
clean_data
# Out:
# ["Pets change our lives & become a part of our families ❤️ That's why our members offer many solutions to help you to enjoy a long-lasting bond with your happy & healthy pet 🐱🐶 #MorethanMedicine #PetCare #PetsareFamily ",
#  'Another spot of our #morethanmedicine bus in #bristol this week! If you need support with your cancer diagnosis call us on 0303 3000 118. #livingwellwithcancer ',
#  'What a great team \u2066@HealthSourceOH\u2069 \u2066@Local12\u2069 #morethanmedicine ',
#  'What a great team \u2066@HealthSourceOH\u2069 \u2066@Local12\u2069 #morethanmedicine ',
#  'What a great team \u2066@HealthSourceOH\u2069 \u2066@Local12\u2069 #morethanmedicine ',
#  'What a great team \u2066@HealthSourceOH\u2069 \u2066@Local12\u2069 #morethanmedicine ',
#  'Will you be at #FIX19? Want a preview of @AG_EM33 story? Then check back Monday for #ChangeOfHeart where we sat down with Alin to discuss her new life since her heart #transplant #MoreThanMedicine ',
# ...

# %%
file = open('sample.txt', 'w+')
for i in range (len(clean_data)):
    file.write(clean_data[i] + "\n")

# %% [markdown]
# # Cleaning Duplicated Data
